# %% [markdown]
# # Mushroom Project:

# %% [markdown]
# # Data Set Information:

# %% [markdown]
# This data set includes descriptions of hypothetical samples corresponding to 23 species of gilled mushrooms in the Agaricus and Lepiota Family (pp. 500-525). Each species is identified as definitely edible, definitely poisonous, or of unknown edibility and not recommended. This latter class was combined with the poisonous one. The Guide clearly states that there is no simple rule for determining the edibility of a mushroom; no rule like ``leaflets three, let it be'' for Poisonous Oak and Ivy.

# %%
import pandas as pd

# %%
df=pd.read_csv('Mushroom Project.csv')
df.head(10)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
# 5     e         x           y         y       t    a               f
# 6     e         b           s         w       t    a               f
# 7     e         b           y         w       t    l               f
# 8     p         x           y         w       t    p               f
# 9     e         b           s         y       t    a               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# ...

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %% [markdown]
# # About Columns:

# %% [markdown]
# 1.Class
#
# The Family to which specific Mushroom belongs. This is our target column.
#
# 2.Cap-Shape
#
# Shape of Mushroom (upper side)
#
# 3.Cap Surface
#
# Surface of Mushroom
#
# 4.Cap Color
#
# Color of Mushroom
#
# 5.Bruises
#
# Inhury appearing on body, due to blow or impact.
#
# 6.Odor
#
# A unpleasant smell.
#
# 7.Gill-attachment
#
# Mushroom gill attachments.
#
# 8.Gill-spacing
#
# Gill spacing of mushrooms.
#
# 9.Gill-Size
#
# Gill size of mushroom
#
# 10.Gill-Color
#
# Gill color of mushroom
#
# 11.Stalk-Shape
#
# A slender upwright object or supporting or connecting part
#
# 12.Stalk-Root
#
# stalk-like feature supporting the cap of a mushroom
#
# 13.Stalk-Surface-Above-Ring
#
# Surface above Stalk ring
#
# 14.Stalk-Surface-Below-Ring
#
# Surface below Stalk ring
#
# 15.Stalk-color-above-ring
#
# Color of stalk above ring
#
# 16.Stalk-color-below-ring
#
# Color of stalk below ring
#
# 17.Veil-type
#
# The thin membrane that covers the cap and stalk of an immature mushroom.
#
# 18.Veil-color
#
# Temporary structure of tissue found on the fruiting bodies of some basidiomycete fungi, typically agarics.
#
# 19.Ring-number
#
# A circle of mushrooms in a grassy area.
#
# 20.Ring-type
#
# Fairy rings are mushrooms that appear in a circular formation, usually in forests or grassy areas.
#
# 21.Spore-print-color
#
# The spore print is the powdery deposit obtained by allowing spores of a fungal fruit body to fall onto a surface underneath.
#
# 22.Population
#
# The population of Mushrooms in certain region
#
# 23.Habitat
#
# Types of Mushrooms grown in different region.

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
df.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %% [markdown]
# # Changing object to int values using LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lencode=LabelEncoder()
df['class']=lencode.fit_transform(df['class'])
df['cap-shape']=lencode.fit_transform(df['cap-shape'])
df['cap-surface']=lencode.fit_transform(df['cap-surface'])
df['cap-color']=lencode.fit_transform(df['cap-color'])
df['bruises']=lencode.fit_transform(df['bruises'])
df['odor']=lencode.fit_transform(df['odor'])
df['gill-attachment']=lencode.fit_transform(df['gill-attachment'])
df['gill-spacing']=lencode.fit_transform(df['gill-spacing'])
df['gill-size']=lencode.fit_transform(df['gill-size'])
df['gill-color']=lencode.fit_transform(df['gill-color'])
df['stalk-shape']=lencode.fit_transform(df['stalk-shape'])
df['stalk-root']=lencode.fit_transform(df['stalk-root'])
df['stalk-surface-above-ring']=lencode.fit_transform(df['stalk-surface-above-ring'])
df['stalk-surface-below-ring']=lencode.fit_transform(df['stalk-surface-below-ring'])
df['stalk-color-above-ring']=lencode.fit_transform(df['stalk-color-above-ring'])
df['stalk-color-below-ring']=lencode.fit_transform(df['stalk-color-below-ring'])
df['veil-type']=lencode.fit_transform(df['veil-type'])
df['veil-color']=lencode.fit_transform(df['veil-color'])
df['ring-number']=lencode.fit_transform(df['ring-number'])
df['ring-type']=lencode.fit_transform(df['ring-type'])
df['spore-print-color']=lencode.fit_transform(df['spore-print-color'])
df['population']=lencode.fit_transform(df['population'])
df['habitat']=lencode.fit_transform(df['habitat'])
df.head(10)
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
# 5      0          5            3          9        1     0                1
# 6      0          0            2          8        1     0                1
# 7      0          0            3          8        1     3                1
# 8      1          5            3          8        1     6                1
# 9      0          0            2          9        1     0                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# Scatterplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.scatter(x='cap-shape',y='class',data=df)
plt.show()

# %% [markdown]
# Here we can see 'cap-shape' has been distributed in the range (0-5)

# %%
plt.scatter(x='cap-surface',y='class',data=df)
plt.show()

# %% [markdown]
# Here we can see 'cap-surface' has been distributed in the range (0-3)

# %%
plt.scatter(x='cap-color',y='class',data=df)
plt.show()

# %% [markdown]
# Here we can see 'cap-color' has been distributed in the range (0-9)

# %%
plt.scatter(x='bruises',y='class',data=df)
plt.show()

# %% [markdown]
# Here we can see 'bruises' has been distributed in the range (0-1)

# %%
plt.scatter(x='odor',y='class',data=df)
plt.show()

# %% [markdown]
# Here we can see 'odor' has been distributed in the range (0-5)

# %%
plt.scatter(x='gill-attachment',y='class',data=df)
plt.show()

# %% [markdown]
# Here we can see 'gill-attachment' has been distributed in the range (0-1)

# %%
plt.scatter(x='gill-spacing',y='class',data=df)
plt.show()

# %% [markdown]
# Here we can see 'gill-spacing' has been distributed in the range (0-5)

# %%
plt.scatter(x='gill-size',y='class',data=df)
plt.show()

# %% [markdown]
# Here we can see 'gill-size' has been distributed in the range (0-1)

# %%
plt.scatter(x='gill-color',y='class',data=df)
plt.show()

# %% [markdown]
# Here we can see 'gill-color' has been distributed in the range (0-11)

# %%
plt.scatter(x='gill-attachment',y='class',data=df)
plt.show()

# %% [markdown]
# Here we can see 'gill-attachment' has been distributed in the range (0-1)

# %%
plt.scatter(x='stalk-shape',y='class',data=df)
plt.show()

# %% [markdown]
# Here we can see 'stalk-shape' has been distributed in the range (0-1)

# %%
plt.scatter(x='stalk-root',y='class',data=df)
plt.show()

# %% [markdown]
# Here we can see 'stalk-root' has been distributed in the range (0-4)

# %%
plt.scatter(x='stalk-surface-above-ring',y='class',data=df)
plt.show()

# %% [markdown]
# Here we can see 'stalk-surface-above-ring' has been distributed in the range (0-3)

# %%
plt.scatter(x='stalk-surface-below-ring',y='class',data=df)
plt.show()

# %% [markdown]
# Here we can see 'stalk-surface-below-ring' has been distributed in the range (0-3)

# %%
plt.scatter(x='stalk-color-above-ring',y='class',data=df)
plt.show()

# %% [markdown]
# Here we can see 'stalk-color-above-ring' has been distributed in the range (2-7)

# %%
plt.scatter(x='stalk-color-below-ring',y='class',data=df)
plt.show()

# %% [markdown]
# Here we can see 'stalk-color-below-ring' has been distributed in the range (2-7)

# %%
plt.scatter(x='veil-type',y='class',data=df)
plt.show()

# %% [markdown]
# Here we can see 'veil-type' has been distributed in the range-(0)

# %%
plt.scatter(x='veil-color',y='class',data=df)
plt.show()

# %% [markdown]
# Here we can see 'veil-color' has been distributed in the range (0-2)

# %%
plt.scatter(x='ring-number',y='class',data=df)
plt.show()

# %% [markdown]
# Here we can see 'ring-number' has been distributed in the range (1-2)

# %%
plt.scatter(x='ring-type',y='class',data=df)
plt.show()

# %% [markdown]
# Here we can see 'ring-number' has been distributed in the range (0-4)

# %%
plt.scatter(x='spore-print-color',y='class',data=df)
plt.show()

# %% [markdown]
# Here we can see 'spore-print-color' has been distributed in the range (0-8)

# %%
plt.scatter(x='population',y='class',data=df)
plt.show()

# %% [markdown]
# Here we can see 'population' has been distributed in the range (0-5)

# %%
plt.scatter(x='habitat',y='class',data=df)
plt.show()

# %% [markdown]
# Here we can see 'habitat' has been distributed in the range (0-6)

# %% [markdown]
# # Correlation:

# %%
df.corr()
# Out:
#                              class  cap-shape  cap-surface  cap-color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap-shape                 0.052951   1.000000    -0.050454  -0.048203
# cap-surface               0.178446  -0.050454     1.000000  -0.019402
# cap-color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill-attachment           0.129200   0.078865    -0.034180   0.041436
# gill-spacing             -0.348387   0.013196    -0.282306   0.144259
# gill-size                 0.540024   0.054050     0.208100  -0.169464
# gill-color               -0.530566  -0.006039    -0.161017   0.084659
# stalk-shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk-root               -0.379361   0.030191    -0.126245   0.321274
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,13))
sns.heatmap(df.corr(),annot=True,linewidth=0.5,linecolor='white',fmt='.2f',cmap='Blues')
plt.show()

# %% [markdown]
# # Outcome of correlation:

# %% [markdown]
# All the columns are positively correlated with target column.
#
# Max Correlation: gill-size
#
# Min Correlation: gill-color

# %% [markdown]
# # Describing Datasets:

# %%
df.describe()
# Out:
#              class    cap-shape  cap-surface    cap-color      bruises  \
# count  8124.000000  8124.000000  8124.000000  8124.000000  8124.000000
# mean      0.482029     3.348104     1.827671     4.504677     0.415559
# std       0.499708     1.604329     1.229873     2.545821     0.492848
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     2.000000     0.000000     3.000000     0.000000
# 50%       0.000000     3.000000     2.000000     4.000000     0.000000
# 75%       1.000000     5.000000     3.000000     8.000000     1.000000
# max       1.000000     5.000000     3.000000     9.000000     1.000000
#
#               odor  gill-attachment  gill-spacing    gill-size   gill-color  \
# count  8124.000000      8124.000000   8124.000000  8124.000000  8124.000000
# mean      4.144756         0.974151      0.161497     0.309207     4.810684
# std       2.103729         0.158695      0.368011     0.462195     3.540359
# ...

# %%
plt.figure(figsize=(15,12))
sns.heatmap(df.describe().transpose(),annot=True,fmt='0.2f',linewidth=0.2)
plt.xticks(fontsize=18)
plt.yticks(fontsize=15)
plt.title('Variable Summary')
plt.show()

# %% [markdown]
# # Outcome of describe of datasets:

# %% [markdown]
# From above we are determining mean, standard deviation, min. and max. value of each column which will furthur help in data cleaning.
#
# Total number and in datasets:
#
#     1. 8124 rows
#     2. 23 columns
#
# cap-shape:
#
#     1.Mean=3.35
#     2.std=1.6
#     3.max_value=5.00
#     4.min_value=0.00
#
# cap-color:
#
#     1.Mean=4.50
#     2.std=2.55
#     3.max_value=9.00
#     4.min_value=0.00
#
# cap-surface:
#
#     1.Mean=1.83
#     2.std=1.23
#     3.max_value=3.00
#     4.min_value=0.00
#
# bruises:
#
#     1.Mean=0.42
#     2.std=0.49
#     3.max_value=1.00
#     4.min_value=0.00
#
# odor:
#
#     1.Mean=4.14
#     2.std=2.10
#     3.max_value=8.00
#     4.min_value=0.00
#
# gill-attachment:
#
#     1.Mean=0.97
#     2.std=0.16
#     3.max_value=1.00
#     4.min_value=0.00
#
# gill-spacing:
#
#     1.Mean=0.16
#     2.std=0.37
#     3.max_value=1.00
#     4.min_value=0.00
#
# gill-size:
#
#     1.Mean=0.31
#     2.std=0.46
#     3.max_value=1.00
#     4.min_value=0.00
#
# gill-color:
#
#     1.Mean=4.81
#     2.std=3.54
#     3.max_value=11.00
#     4.min_value=0.00
#
# stalk-shape:
#
#     1.Mean=0.57
#     2.std=0.50
#     3.max_value=1.00
#     4.min_value=0.00
#
# stalk-root:
#
#     1.Mean=1.11
#     2.std=1.06
#     3.max_value=4.00
#     4.min_value0.00
#
# stalk-surface-above-ring:
#
#     1.Mean=1.58
#     2.std=0.62
#     3.max_value=3.00
#     4.min_value=0.00
#
# stalk-surface-below-ring:
#
#     1.Mean=1.60
#     2.std=0.68
#     3.max_value=3.00
#     4.min_value=0.00
#
# stalk-color-above-ring:
#
#     1.Mean=5.82
#     2.std=1.90
#     3.max_value=8.00
#     4.min_value=0.00
#
# stalk-color-below-ring:
#
#     1.Mean=5.79
#     2.std=1.91
#     3.max_value=8.00
#     4.min_value=0.00
#
# veil-type:
#
#     1.Mean=0.00
#     2.std=0.00
#     3.max_value=0.00
#     4.min_value=0.00
#
# veil-color:
#
#     1.Mean=1.97
#     2.std=0.24
#     3.max_value=3.00
#     4.min_value=0.00
#
# ring-number:
#
#     1.Mean=1.07
#     2.std=0.27
#     3.max_value=2.00
#     4.min_value=0.00
#
# ring-type:
#
#     1.Mean=2.29
#     2.std=1.80
#     3.max_value=4.00
#     4.min_value=0.00
#
# spore-print-color:
#
#     1.Mean=3.60
#     2.std=2.38
#     3.max_value=8.00
#     4.min_value=0.00
#
# population:
#
#     1.Mean=3.64
#     2.std=1.25
#     3.max_value=5.00
#     4.min_value=0.00
#
# habitat:
#
#     1.Mean=1.51
#     2.std=1.72
#     3.max_value=6.00
#     4.min_value=0.00
#
# class:
#
#     1.Mean=0.48
#     2.std=0.50
#     3.max_value=1.00
#     4.min_value=0.00
# class is the target value.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   int32
#  1   cap-shape                 8124 non-null   int32
#  2   cap-surface               8124 non-null   int32
#  3   cap-color                 8124 non-null   int32
#  4   bruises                   8124 non-null   int32
#  5   odor                      8124 non-null   int32
#  6   gill-attachment           8124 non-null   int32
#  7   gill-spacing              8124 non-null   int32
#  8   gill-size                 8124 non-null   int32
#  9   gill-color                8124 non-null   int32
#  10  stalk-shape               8124 non-null   int32
#  11  stalk-root                8124 non-null   int32
#  12  stalk-surface-above-ring  8124 non-null   int32
#  13  stalk-surface-below-ring  8124 non-null   int32
# ...

# %% [markdown]
# From above we can have columns datatype and memory used by the dataframe.

# %% [markdown]
# # Outliers Checking:

# %%
df.plot(kind='box',subplots=True,layout=(4,6),figsize=(15,18),color='green')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# From above we can see that columns['cap-shape','cap-surface','cap-color','bruises','odor','gill-size','gill-color','stalk-shape','stalk-surface-above-ring','stalk-surface-below-ring','ring-type','spore-print-color'] have no outliers, columns ['stalk-root','stalk-color-above-ring','stalk-color-below-ring','population','habitat'] has less outliers, while our target column 'class' have no outlires.

# %%
df.skew()
# Out:
# class                       0.071946
# cap-shape                  -0.247052
# cap-surface                -0.590859
# cap-color                   0.706965
# bruises                     0.342750
# odor                       -0.080790
# gill-attachment            -5.977076
# gill-spacing                1.840088
# gill-size                   0.825797
# gill-color                  0.061410
# stalk-shape                -0.271345
# stalk-root                  0.947852
# stalk-surface-above-ring   -1.098739
# stalk-surface-below-ring   -0.757703
# stalk-color-above-ring     -1.835434
# stalk-color-below-ring     -1.791593
# veil-type                   0.000000
# veil-color                 -6.946944
# ring-number                 2.701657
# ring-type                  -0.290018
# spore-print-color           0.548426
# population                 -1.413096
# habitat                     0.985548
# dtype: float64

# %% [markdown]
# Outcome of the skewness: Skewness threshold is +/-0.5. Columns which are having Skewness
#
#     cap-surface
#     cap-color
#     gill-attachment
#     gill-spacing
#     gill-size
#     stalk-root
#     stalk-surface-above-ring
#     stalk-surface-below-ring
#     stalk-color-above-ring
#     stalk-color-below-ring
#     veil-color
#     ring-number
#     spore-print-color
#     population
#     habitat

# %% [markdown]
# # Normal Distribution Curve:

# %%
sns.distplot(df['cap-surface'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The data is not normalised, building blocks are out of the normalised curve

# %%
sns.distplot(df['cap-color'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The data is not normalised, building blocks are out of the normalised curve

# %%
sns.distplot(df['gill-attachment'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The data is not normalised, building blocks are out of the normalised curve

# %%
sns.distplot(df['gill-spacing'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The data is not normalised, building blocks are out of the normalised curve

# %%
sns.distplot(df['gill-size'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The data is not normalised, building blocks are out of the normalised curve

# %%
sns.distplot(df['stalk-root'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The data is not normalised, building blocks are out of the normalised curve

# %%
sns.distplot(df['stalk-surface-above-ring'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The data is not normalised, building blocks are out of the normalised curve

# %%
sns.distplot(df['stalk-surface-below-ring'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The data is not normalised, building blocks are out of the normalised curve

# %%
sns.distplot(df['stalk-color-above-ring'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The data is not normalised, building blocks are out of the normalised curve

# %%
sns.distplot(df['stalk-color-below-ring'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The data is not normalised, building blocks are out of the normalised curve

# %%
sns.distplot(df['veil-color'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The data is not normalised, building blocks are out of the normalised curve

# %%
sns.distplot(df['ring-number'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The data is not normalised, building blocks are out of the normalised curve

# %%
sns.distplot(df['spore-print-color'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The data is not normalised, building blocks are out of the normalised curve

# %%
sns.distplot(df['population'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The data is not normalised, building blocks are out of the normalised curve

# %%
sns.distplot(df['habitat'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# The data is not normalised, building blocks are out of the normalised curve

# %% [markdown]
# # The normal distribution shows that the data is skewed.

# %% [markdown]
# As all the values are categorical values, there is no need to remove outliers and skewness. We can process with the training and testing of data.

# %% [markdown]
# Dividing data in features and vectors

# %%
x=df_new.iloc[:,1:23]
y=df_new.iloc[:,0]

# %%
y.value_counts()
# Out:
# 0    3488
# 1    3080
# Name: class, dtype: int64

# %% [markdown]
# # Data Balancing of target column.

# %% [markdown]
# Applying SMOTE

# %%
from imblearn.over_sampling import SMOTE

# %%
smt=SMOTE()
trainx,trainy=smt.fit_resample(x,y)

# %%
np.bincount(y)
# Out:
# array([3488, 3080], dtype=int64)

# %%
trainx.value_counts()
# Out:
# cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  gill-spacing  gill-size  gill-color  stalk-shape  stalk-root  stalk-surface-above-ring  stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  veil-color  ring-number  ring-type  spore-print-color  population  habitat
# 2          3            3          0        2     1                0             0          3           0            1           1                         1                         4                       4                       2           1            2          1                  5           0          4
# 5          3            2          0        8     1                0             1          0           1            0           1                         2                         6                       7                       2           1            0          7                  4           0          3
# ...

# %%
print('After applying SMOTE',trainy.value_counts())
print('Before applying SMOTE',y.value_counts())
# Out:
# After applying SMOTE 0    3488
# 1    3488
# Name: class, dtype: int64
# Before applying SMOTE 0    3488
# 1    3080
# Name: class, dtype: int64

# %% [markdown]
# As we can see after applying SMOTE all the target column data is equally divided.

# %% [markdown]
# # Since the outcome has only two variable we will use binary classification model.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Splitting the dataframe:

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(trainx,trainy,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
        print('At random state',i,'The model performs very well')
        print('At random state',i)
        print('Training r2_score is:-',accuracy_score(y_train,pred_train)*100)
        print('Testing r2_score is:-',accuracy_score(y_test,pred_test)*100)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(trainx,trainy,random_state=306,test_size=0.20)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50       690
#            1       0.51      0.52      0.52       706
#
#     accuracy                           0.51      1396
#    macro avg       0.51      0.51      0.51      1396
# weighted avg       0.51      0.51      0.51      1396

# %% [markdown]
# # Cross Validation score for logistic regression:

# %%
pred_lr=lr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss=accuracy_score(y_test,pred_lr)
for j in range(2,30):
    lsscore=cross_val_score(lr,trainx,trainy,cv=j)
    lsc=lsscore.mean()
    print('At cv:-',j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',lss*100)
    print('\n')
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# Since cross validation score accuracy score are almost same. We are heading with a good approach.

# %%
lsscore_selected=cross_val_score(lr,trainx,trainy,cv=50).mean()
print('The cv score is :',lsscore_selected,'\nThe accuracy score ids :',lss)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# # The model Prediction with data:

# %%
from sklearn.metrics import roc_curve,auc
fpr, tpr, thresholds= roc_curve(pred_test,y_test)
roc_auc= auc(fpr,tpr)

plt.figure()
plt.plot(fpr,tpr,color='darkorange',lw=10,label='ROC Curve (area= %0.2f)'%roc_auc)
plt.plot([0,1],[0,1],color='navy',lw=10,linestyle='--')
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristics')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # Since the model without outliers performing well, we will select that dataframe.

# %% [markdown]
# # Model Saving:

# %%
import pickle
filename= 'inhouse_mushroom.pk1'
pickle.dump(lr,open(filename,'wb'))

# %% [markdown]
# # Conclusion:

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(lr.predict(x_test))
df_com=pd.DataFrame({'original':a,'predicted':predicted},index=range(len(a)))
df_com
# Out:
#       original  predicted
# 0            0          0
# 1            0          0
# 2            1          1
# 3            1          1
# 4            1          1
# ...        ...        ...
# 1391         0          0
# 1392         1          1
# 1393         1          1
# 1394         1          0
# 1395         1          1
#
# [1396 rows x 2 columns]

# %% [markdown]
# # The model Prediction with data:

# %%
from sklearn.metrics import roc_curve,auc
roc_auc=auc(fpr,tpr)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,color='darkorange',label='roc curve (area=%0.2f)'%roc_auc)
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title('lgr')
plt.legend(loc='lower right')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
